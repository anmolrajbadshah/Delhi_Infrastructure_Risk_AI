# %%
import sys
sys.executable
print(sys.executable)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python310\python.exe

# %%
import geopandas as gpd
gpd.__version__
# Out:
# '1.1.2'

# %%
import os

os.listdir("gis/raw")
# Out:
# ['india-260115.osm.pbf']

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\hp\\Documents\\ML_Projects\\Delhi_Infrastructure_Risk_AI\\notebooks'

# %%
import os
os.chdir("..")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\hp\\Documents\\ML_Projects\\Delhi_Infrastructure_Risk_AI'

# %%
os.listdir("gis")
# Out:
# []
